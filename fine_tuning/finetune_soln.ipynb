# %% [markdown]
# ## CNN Transfer Learning on Cats-Dogs Classification - Fine Tune
#
# #### Finetune top layers and classification layers to classify cats vs. dogs.
# Adapted from https://www.tensorflow.org/tutorials/images/transfer_learning
#
# -----

# %%
# !pip install tensorflow -q

# %%
# !pip install scikit-learn -q

# %% [markdown]
# ### Setup

# %%
# !pip install matplotlib -q

# %%
# !pip install numpy -q

# %%
# Set logging level
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  

import tensorflow as tf
tf.get_logger().setLevel('ERROR')

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras import applications
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array, load_img

from sklearn.metrics import classification_report 
import matplotlib.pyplot as plt
import numpy as np
import random
import os
import time

# Verify the TensorFlow version
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.13.0

# %%
print (tf.__version__)
# !python --version
# Out:
# 2.13.0
# Python 3.11.5

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
# !nvidia-smi
# Out:
# Thu Jul 11 19:32:48 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.76                 Driver Version: 550.76         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L40                     Off |   00000000:CA:00.0 Off |                    0 |
# | N/A   35C    P0             93W /  300W |   43868MiB /  46068MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA L40                     Off |   00000000:E1:00.0 Off |                    0 |
# | N/A   35C    P0             95W /  300W |     489MiB /  46068MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
# Set random generator seed
seed = 1234

# Set Python seed, NumPy seed, and TensorFlow seed
tf.keras.utils.set_random_seed(seed)

# Potential randomness from CUDNN
# os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC']= '1'

# %% [markdown]
# ### Set image location and dimensions

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
path_to_zip = tf.keras.utils.get_file('cats_and_dogs.zip', origin=_URL, extract=True)
PATH = os.path.join(os.path.dirname(path_to_zip), 'cats_and_dogs_filtered')
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68606236/68606236 [==============================] - 1s 0us/step
# Found 2000 files belonging to 2 classes.

# %%
PATH
# Out:
# '/home/jovyan/.keras/datasets/cats_and_dogs_filtered'

# %%
import shutil

# %%
shutil.unpack_archive(PATH, extract_dir='/home/jovyan/data')
# Out:
# ---------------------------------------------------------------------------
# ReadError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 shutil.unpack_archive(PATH, extract_dir='/home/jovyan/data')
#
# File /opt/conda/lib/python3.11/shutil.py:1323, in unpack_archive(filename, extract_dir, format, filter)
#    1321 format = _find_unpack_format(filename)
#    1322 if format is None:
# -> 1323     raise ReadError("Unknown archive format '{0}'".format(filename))
#    1325 func = _UNPACK_FORMATS[format][1]
#    1326 kwargs = dict(_UNPACK_FORMATS[format][2]) | filter_kwargs
#
# ReadError: Unknown archive format '/home/jovyan/.keras/datasets/cats_and_dogs_filtered'

# %%
import subprocess 
import os 
# Define the URL and the target directory 
url = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.z
jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.988.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.987.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.986.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.985.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.984.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.983.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.982.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.981.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.980.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.979.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.978.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.977.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.976.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.975.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.974.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.973.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.972.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.971.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.970.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.969.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.968.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.967.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.966.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.965.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.964.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.963.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.962.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.961.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.960.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.959.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.958.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.957.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.956.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.955.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.954.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.953.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.952.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.951.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.950.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.949.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.948.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.947.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.946.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.945.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.944.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.943.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.942.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.941.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.940.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.939.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.938.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.937.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.936.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.935.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.934.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.933.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.932.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.931.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.930.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.929.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.928.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.927.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.926.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.925.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.924.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.923.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.922.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.921.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.920.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.919.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.918.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.917.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.916.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.915.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.914.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.913.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.912.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.911.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.910.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.909.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.908.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.907.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.906.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.905.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.904.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.903.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.902.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.901.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.900.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.899.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.898.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.897.jpg
#   inflating: /home/jovyan/data/cats_and_dogs_filtered/train/cats/cat.896.jpg

# %%
import os

# Define the home directory and data path
HOME = os.path.expanduser("~")
data_path = os.path.join(HOME, 'data', 'cats_and_dogs_filtered')

# Print the data path
print(f"Data path: {data_path}")

# Define the directories for train, validation, and test data
train_data_dir = os.path.join(data_path, 'train')
val_data_dir = os.path.join(data_path, 'validation')
test_data_dir = os.path.join(data_path, 'test')

# Print the paths
print(f"Train path: {train_data_dir}")
print(f"Validation path: {val_data_dir}")
print(f"Test path: {test_data_dir}")
# Out:
# Data path: /home/jovyan/data/cats_and_dogs_filtered
# Train path: /home/jovyan/data/cats_and_dogs_filtered/train
# Validation path: /home/jovyan/data/cats_and_dogs_filtered/validation
# Test path: /home/jovyan/data/cats_and_dogs_filtered/test

# %%
# Image dimensions
img_width, img_height = 224, 224 
IMG_SIZE = (img_width,img_height)
IMG_SHAPE = IMG_SIZE + (3,)

# Print image shape
print(IMG_SHAPE)
# Out:
# (224, 224, 3)

# %% [markdown]
# ### Prepare data

# %%
# Batch size
BATCH_SIZE = 16

# Data setup
rescale = tf.keras.applications.mobilenet_v2.preprocess_input
train_datagen      = ImageDataGenerator(shear_range = 0.2, zoom_range = 0.2, horizontal_flip = True, preprocessing_function = rescale)
validation_datagen = ImageDataGenerator(preprocessing_function = rescale)
test_datagen       = ImageDataGenerator(preprocessing_function = rescale)

# Set up generator to read images found in subfolders of training data directory,
# and indefinitely generate batches of image data (scaled).  This is for training data.
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=IMG_SIZE,
    batch_size = BATCH_SIZE,
    class_mode='binary', 
    shuffle = True,
    seed = seed)           

# Set up generator to generate batched of validation data for model
validation_generator = validation_datagen.flow_from_directory(
    val_data_dir,
    target_size=IMG_SIZE,
    batch_size = BATCH_SIZE,
    class_mode='binary',
    shuffle = False, 
    seed = seed)

# Set up generator to generate batched of test data for model
test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=IMG_SIZE,
    batch_size = BATCH_SIZE,
    class_mode='binary',
    shuffle = False,
    seed = seed)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1001 images belonging to 2 classes.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 30
#      21 validation_generator = validation_datagen.flow_from_directory(
#      22     val_data_dir,
#      23     target_size=IMG_SIZE,
#    (...)
#      26     shuffle = False,
#      27     seed = seed)
#      29 # Set up generator to generate batched of test data for model
# ---> 30 test_generator = test_datagen.flow_from_directory(
#      31     test_data_dir,
#      32     target_size=IMG_SIZE,
#      33     batch_size = BATCH_SIZE,
#      34     class_mode='binary',
#      35     shuffle = False,
#      36     seed = seed)
#
# File /opt/conda/lib/python3.11/site-packages/keras/src/preprocessing/image.py:1648, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1562 def flow_from_directory(
#    1563     self,
#    1564     directory,
#    (...)
#    1578     keep_aspect_ratio=False,
#    1579 ):
#    1580     """Takes the path to a directory & generates batches of augmented data.
#    1581
#    1582     Args:
#    (...)
#    1646             and `y` is a numpy array of corresponding labels.
#    1647     """
# -> 1648     return DirectoryIterator(
#    1649         directory,
#    1650         self,
#    1651         target_size=target_size,
#    1652         color_mode=color_mode,
#    1653         keep_aspect_ratio=keep_aspect_ratio,
#    1654         classes=classes,
#    1655         class_mode=class_mode,
#    1656         data_format=self.data_format,
#    1657         batch_size=batch_size,
#    1658         shuffle=shuffle,
#    1659         seed=seed,
#    1660         save_to_dir=save_to_dir,
#    1661         save_prefix=save_prefix,
#    1662         save_format=save_format,
#    1663         follow_links=follow_links,
#    1664         subset=subset,
#    1665         interpolation=interpolation,
#    1666         dtype=self.dtype,
#    1667     )
#
# File /opt/conda/lib/python3.11/site-packages/keras/src/preprocessing/image.py:563, in DirectoryIterator.__init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     561 if not classes:
#     562     classes = []
# --> 563     for subdir in sorted(os.listdir(directory)):
#     564         if os.path.isdir(os.path.join(directory, subdir)):
#     565             classes.append(subdir)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jovyan/data/cats_and_dogs_filtered/test'

# %% [markdown]
# ### Load model from feature extraction
# Load model saved from feature extraction.  Weights in last blocks and top model will be adjusted.  All other weights are frozen.

# %%
model = tf.keras.models.load_model('models/features_model')

# %%
# Uncomment to list layers in model
# print("Number of layers in the base model: ", len(model.layers[1].layers))
# list(enumerate(model.layers[1].layers))

# %%
## Freeze all weights of model up to Block 14
model.trainable = True
fine_tune_start = 116
for layer in model.layers[1].layers[:fine_tune_start]:
    layer.trainable = False
    
model.summary()

# %% [markdown]
# ### Fine tune model

# %%
EPOCHS = 20

# Compile model with very slow learning rate
model.compile(
    optimizer = optimizers.Adam(learning_rate = 0.00001),
    loss = losses.BinaryCrossentropy(),
    metrics = ['accuracy'])

# Perform early stopping to avoid overfitting and ModelCheckpoint to save the best model
checkpoint_path = 'tmp/checkpoint'
callbacks = [
    EarlyStopping(
        monitor = 'val_loss', 
        patience = 3, 
        min_delta = 0.001, 
        mode = 'min'),
    ModelCheckpoint(
        filepath=checkpoint_path, 
        monitor = 'val_loss', 
        mode = 'min',          
        save_best_only = True, 
        save_weights_only = True)]

# %%
# %%time

train_history = model.fit(
    train_generator,
    epochs = EPOCHS, 
    validation_data = validation_generator, 
    callbacks = callbacks)

# %%
# Load the best model that was saved using ModelCheckpoint
model.load_weights(checkpoint_path)

# %%
# Save weights from finetuning
model.save("models/finetune_model")

# %%
# Plot train and validation loss
fig, axs = plt.subplots(1,2, figsize= (20,5))
axs[0].plot(train_history.history['loss'])
axs[0].plot(train_history.history['val_loss'])
axs[0].set_title("Train, Val loss history")
axs[0].set_xlabel("Epoch")
axs[0].legend(["Train Loss","Val Loss"])

# Plot train and validation accuracy
axs[1].plot(train_history.history['accuracy'])
axs[1].plot(train_history.history['val_accuracy'])
axs[1].set_title("Train, Val Accuracy history")
axs[1].set_xlabel("Epoch")
axs[1].legend(["Train Accuracy","Val Accuracy"])

# %% [markdown]
# ### Evaluate model

# %%
_, train_accuracy = model.evaluate(train_generator)
print("Train data accuracy:", train_accuracy)

_, test_accuracy = model.evaluate(test_generator)
print("Test data accuracy:", test_accuracy)

# %%
# Get predicted value and the ground truth value of test data
pred = (model.predict(test_generator) > 0.5).astype("int32")
true = test_generator.classes

# %%
# Get evaluation metrics for test data
print(classification_report(y_true= true, y_pred = pred, target_names=['cats', 'dogs'], digits=4))

# %% [markdown]
# ### Perform inference on test images

# %%
def image_loader(img_file):
    """load individual images"""
    img = load_img(img_file, target_size = (img_width, img_height))
    imgplot = plt.imshow(img)
    plt.show()
    img = (img_to_array(img)/127.5)-1.0
    img = np.expand_dims(img, axis = 0) #model input is (1,150,150,3)
    return img

# %%
test_image = data_path + '/test/cats/cat.1070.jpg'
img = image_loader(test_image)
img_y_pred = model.predict(img) 
print(np.round(img_y_pred,5))

# %%
test_image = data_path + '/test/dogs/dog.1233.jpg'
img = image_loader(test_image)
img_y_pred = model.predict(img) 
print(np.round(img_y_pred,5))

# %%
test_image = data_path + '/test/cats/cat.1080.jpg'
img = image_loader(test_image)
img_y_pred = model.predict(img) 
print(np.round(img_y_pred,5))

# %%
test_image = data_path + '/test/dogs/dog.1132.jpg'
img = image_loader(test_image)
img_y_pred = model.predict(img) 
print(np.round(img_y_pred,5))

# %%
test_image = data_path + '/test/dogs/dog.1311.jpg'
img = image_loader(test_image)
img_y_pred = model.predict(img) 
print(np.round(img_y_pred,5))

# %%
test_image = data_path + '/test/cats/cat.1338.jpg'
img = image_loader(test_image)
img_y_pred = model.predict(img) 
print(np.round(img_y_pred,5))

# %%
test_image = data_path + '/test/cats/cat.1342.jpg'
img = image_loader(test_image)
img_y_pred = model.predict(img) 
print(img_y_pred)

# %%
test_image = data_path + '/test/cats/cat.1180.jpg'
img = image_loader(test_image)
img_y_pred = model.predict(img) 
print(np.round(img_y_pred,5))

# %%
test_image = data_path + '/test/cats/cat.1048.jpg'
img = image_loader(test_image)
img_y_pred = model.predict(img) 
print(np.round(img_y_pred,5))

# %%
test_image = data_path + '/test/dogs/dog.1342.jpg'
img = image_loader(test_image)
img_y_pred = model.predict(img) 
print(np.round(img_y_pred,5))

# %%
test_image = data_path + '/test/dogs/dog.1308.jpg'
img = image_loader(test_image)
img_y_pred = model.predict(img) 
print(np.round(img_y_pred,5))
